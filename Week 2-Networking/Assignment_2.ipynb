# %% [markdown]
# **<u>INSTRUCTIONS</u> : I hope you have grasped the concepts taught in our recent lectures on networking. This assignment is designed to deepen your understanding and encourage you to explore further. Questions 3, 4, and 5 are open-ended, allowing you the freedom to delve into these topics as deeply as you wish. I encourage you to search the web, find relevant articles, and implement your findings. Feel free to conduct experiments and share your insights. This is an opportunity for you to engage with the material creatively and critically. Happy researching!**

# %% [markdown]
# # 1

# %% [markdown]
# ```
# Q1. Consider a network consisting of six hosts (A, B, C, D, E, and F) connected via two switches (S1 and S2).
# Switch S1 has four ports connected to A, B, C, and S2, while switch S2 has four ports connected to D, E, F, and S1.
# Initially, both switches lack knowledge of the hosts' locations.
# Explain in detail how the switches handle the following communications (in the specified order):
#
# 	1.	A to F
# 	2.	E to B
# 	3.	S2 to C
# 	4.	A to B
#
# In your explanation, include the role of MAC addresses (m1, m2, m3, m4, m5, m6, ms1, ms2), IP addresses (i1, i2, i3, i4, i5, i6, is1, is2),
# and describe how switches and hosts learn and populate their MAC address and/or ARP tables throughout these communications.
# ```

# %% [markdown]
# ![JPEG image-4F8F-AACC-38-0.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# **Ans :**

# %% [markdown]
# **References :**

# %% [markdown]
# # 2

# %% [markdown]
# ```
# Q2. Consider the network setup below, where three hosts (A, B, and C) are interconnected via two routers (R1 and R2).
# Initially, all routing and ARP tables are empty.
# Explain in detail how each table is populated step by step during the following communications (in the specified sequence):
#
# 	1.	A to B
# 	2.	B to C
# 	3.	C to A
#
# Additionally, analyze what would happen if the order of communications is reversed (i.e., 3 → 2 → 1).
# ```

# %% [markdown]
# ![JPEG image-4179-8266-61-0.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# **Ans :**

# %% [markdown]
# **References :**

# %% [markdown]
# # 3

# %% [markdown]
# ```
# Q3. Explain the following protocols:
# HTTP, SMTP, POP3, IMAP, FTP, SSL, TLS, and HTTPS.
# Describe their functions and how they work in detail.
# (minimum 300 words)
# ```

# %% [markdown]
# **Ans :**

# %% [markdown]
# **References :**

# %% [markdown]
# # 4

# %% [markdown]
# ```
# Q4. Discuss the roles and functionalities of
# DNS, DHCP, TCP, UDP, ISPs, private IP addresses, NATs, VPNs, and firewalls in detail.
# Explain how each component contributes to network communication and security.
# (minimum 300 words)
# ```

# %% [markdown]
# **Ans :**

# %% [markdown]
# **References :**

# %% [markdown]
# # 5

# %% [markdown]
# ```
# Q5. In the scenario where a user searches for a website and logs in,
# describe the roles of the following components:
#
# - User Device
# - DHCP Server
# - DNS Server
# - Web Server
# - Authentication Server
# - Database Server
# - Internet Service Provider (ISP)
#
# If possible, please provide a flowchart illustrating how these interactions occur during the process.
# ```

# %% [markdown]
# **Ans :**

# %% [markdown]
# **References :**

# %% [markdown]
# # Good Job!!

# %% [markdown]
# How do you feel about networking now? 🙃
